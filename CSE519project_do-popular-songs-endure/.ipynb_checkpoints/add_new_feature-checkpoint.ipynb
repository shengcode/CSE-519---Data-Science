# %%
import pandas as pd
import numpy as np
import csv
import glob
import matplotlib.pyplot as plt
import seaborn as sns

# %%
ALL_SONG_PATH="D:/CSE519/Project/billboard_w_new_features_v7.csv"
FEATURE_ROOT="D:/CSE519/Project/song_feature/"
NEW_FEATURE_CSV_PATH="D:/CSE519/Project/allsong_feature.csv"

# %% [markdown]
# # Read all song information and drop duplicates

# %%
allSong= pd.read_csv(ALL_SONG_PATH, encoding='latin-1')
allSong.sort_values(by=["weekid"], ascending=True)
allSong.drop_duplicates(subset=['songid'], keep='first', inplace=True )
allSong.shape
# Out:
# (27278, 17)

# %% [markdown]
# # preprocess the all song data frame  with "/" in song name

# %%
def split_funct(x):
    song=x['song']
    if "/" in song:
        return song.split("/")
    else:
        return []
allSong['split']= allSong.apply(lambda x: split_funct(x), axis=1)

# %% [markdown]
# # double check the split function works

# %%
withSplit=allSong['split'].map(lambda x: len(x)>=2)
print(allSong[withSplit].shape)
withNoSplit=allSong['split'].map(lambda x: x==[])
print(allSong[withNoSplit].shape)
allSong.head()
withSlash = allSong['song'].map(lambda x: "/" in x)
print(allSong[withSlash].shape)
withNoSlash=allSong['song'].map(lambda x: "/" not in x)
print(allSong[withNoSlash].shape)
# Out:
# (263, 18)
# (27015, 18)
# (263, 18)
# (27015, 18)

# %% [markdown]
# # All features that needs to merge

# %%
def process_feature_name(list_feature_name):
    new_list_feature=[]
    for file in list_feature_name:
        a=file.replace('D:/CSE519/Project/song_feature\songs-','')
        b=a.replace(".csv",'')     
        new_list_feature.append(b)
    return new_list_feature

list_feature_name=glob.glob(FEATURE_ROOT+"*.csv")
print(len(list_feature_name))
feature_name=process_feature_name(list_feature_name)
print(len(feature_name))
# Out:
# 26
# 26

# %%
def check_split_func(song_row, featureSong, featureArtist, feature_name):
    split_song =song_row['split']
    if ((featureSong in split_song) & (featureArtist==song_row['performer'])):
        song_row[feature_name]=1   
    
def slash_func(featureSong_row,  allSong, feature_name):
    featureSong=featureSong_row['song']
    featureArtist=featureSong_row['artist']
    if "/" not in featureSong:
        if (allSong.loc[ (allSong.song==featureSong)  & (allSong.performer==featureArtist) ].shape[0]!=0):
            allSong.loc[ ((allSong.song == featureSong) & (allSong.performer==featureArtist)) , feature_name] = 1
        else:            
            allSong.apply(lambda x: check_split_func(x, featureSong, featureArtist, feature_name), axis=1)
    if "/" in featureSong:
        featureSongs_array=featureSong.split("/")
        for songs in featureSongs_array:
            if (allSong.loc[(allSong.song==featureSong)  & (allSong.performer==featureArtist)].shape[0]!=0):
                allSong.loc[((allSong.song == featureSong) & (allSong.performer==featureArtist)), feature_name] = 1
            else:            
                allSong.apply(lambda x: check_split_func(x, songs,featureArtist, feature_name), axis=1)

# %%
for idx, feature in enumerate (feature_name):    
    feature_df=pd.read_csv(list_feature_name[idx], encoding='latin-1')
    allSong[feature]=0
    feature_df.apply(lambda x: slash_func(x, allSong,feature), axis=1)
    print(idx)

# %%
allSong.to_csv(NEW_FEATURE_CSV_PATH, index=False)

# %%
allSong.shape

# %%
allSong=pd.read_csv(NEW_FEATURE_CSV_PATH,sep='\t')
allSong.drop("Unnamed: 0", inplace=True,axis=1)
allSong.shape
# Out:
# (27278, 44)

# %%
allSong.head(1)
# Out:
#                                                  url      weekid  \
# 0  http://www.billboard.com/charts/hot-100/1990-0...  1990-05-05
#
#    week_position       song           performer                       songid  \
# 0             84  "B" Girls  Young And Restless  "B" GirlsYoung And Restless
#
#    instance  previous_week_position  peak_position  weeks_on_chart   ...     \
# 0         1                     NaN             54              15   ...
#
#    karaoke  lullabies  mtvawards  phonecall  politicians  sportingevents  \
# 0        0          0          0          0            0               0
#
#    tvshow weddings  wonoscars  wordcup
# 0       0        0          0        0
#
# [1 rows x 44 columns]

# %% [markdown]
# # song features and the matches we found

# %%
for idx, feature in enumerate (feature_name):    
    feature_df=pd.read_csv(list_feature_name[idx], encoding='latin-1')
    print ("the songs with feature "+ feature+ " "+ str(feature_df.shape))
    allsong_with_feature=allSong.loc[allSong[feature]==1]
    print("the matches that we finally find out "+ str(allsong_with_feature.shape))
# Out:
# the songs with feature artistdied (46, 2)
# the matches that we finally find out (22, 44)
# the songs with feature christmas (225, 2)
# the matches that we finally find out (18, 44)
# the songs with feature church (102, 2)
# the matches that we finally find out (4, 44)
# the songs with feature classical (73, 2)
# the matches that we finally find out (0, 44)
# the songs with feature commercials (699, 2)
# the matches that we finally find out (272, 44)
# the songs with feature concerts (35, 2)
# the matches that we finally find out (13, 44)
# the songs with feature easter (20, 2)
# the matches that we finally find out (0, 44)
# the songs with feature fourthofjuly (25, 2)
# the matches that we finally find out (6, 44)
# the songs with feature funerals (39, 2)
# the matches that we finally find out (11, 44)
# the songs with feature graduations (71, 2)
# the matches that we finally find out (38, 44)
# the songs with feature grammys (450, 2)
# the matches that we finally find out (244, 44)
# the songs with feature halloween (35, 2)
# the matches that we finally find out (9, 44)
# the songs with feature inmovieclueless (15, 2)
# the matches that we finally find out (7, 44)
# the songs with feature inmovies (2239, 2)
# the matches that we finally find out (633, 44)
# the songs with feature inplays (332, 2)
# the matches that we finally find out (16, 44)
# the songs with feature intvshows (616, 2)
# the matches that we finally find out (183, 44)
# the songs with feature karaoke (34, 2)
# the matches that we finally find out (25, 44)
# the songs with feature lullabies (37, 2)
# the matches that we finally find out (1, 44)
# the songs with feature mtvawards (110, 2)
# the matches that we finally find out (57, 44)
# the songs with feature phonecall (36, 2)
# the matches that we finally find out (9, 44)
# the songs with feature politicians (55, 2)
# the matches that we finally find out (22, 44)
# the songs with feature sportingevents (98, 2)
# the matches that we finally find out (31, 44)
# the songs with feature tvshow (205, 2)
# the matches that we finally find out (41, 44)
# the songs with feature weddings (82, 2)
# the matches that we finally find out (39, 44)
# the songs with feature wonoscars (55, 2)
# the matches that we finally find out (16, 44)
# the songs with feature wordcup (23, 2)
# the matches that we finally find out (1, 44)

# %%
df_array=[]
for idx, feature in enumerate (feature_name):    
    allsong_with_feature=allSong.loc[allSong[feature]==1]
    df_array.append(allsong_with_feature)
#     print("the matches that we finally find out "+ str(allsong_with_feature.shape))

# %%
print(feature_name[0])

columns_to_drop=feature_name[1:25]
df_mody=df_array[0].drop(columns_to_drop, axis=1)
df_mody
# Out:
# artistdied
#                                                      url      weekid  \
# 117    http://www.billboard.com/charts/hot-100/1980-1...  1980-11-01
# 163    http://www.billboard.com/charts/hot-100/1968-0...  1968-01-27
# 293    http://www.billboard.com/charts/hot-100/1982-1...  1982-10-30
# 442    http://www.billboard.com/charts/hot-100/1965-0...  1965-01-30
# 3891   http://www.billboard.com/charts/hot-100/2013-0...  2013-06-08
# 5196   http://www.billboard.com/charts/hot-100/1997-1...  1997-12-20
# 5216   http://www.billboard.com/charts/hot-100/1958-1...  1958-11-22
# 7009   http://www.billboard.com/charts/hot-100/1995-1...  1995-12-30
# 7324   http://www.billboard.com/charts/hot-100/1971-0...  1971-09-11
# 9526   http://www.billboard.com/charts/hot-100/1997-0...  1997-04-26
# 11090  http://www.billboard.com/charts/hot-100/1974-0...  1974-03-02
# 11787  http://www.billboard.com/charts/hot-100/1959-0...  1959-02-21
# 14946  http://www.billboard.com/charts/hot-100/1971-0...  1971-01-30
# 15009  http://www.billboard.com/charts/hot-100/1972-0...  1972-08-12
# 16361  http://www.billboard.com/charts/hot-100/1984-0...  1984-01-21
# 18148  http://www.billboard.com/charts/hot-100/1996-0...  1996-03-23
# 23747  http://www.billboard.com/charts/hot-100/1973-1...  1973-11-17
# 24957  http://www.billboard.com/charts/hot-100/1981-0...  1981-03-28
# 25523  http://www.billboard.com/charts/hot-100/1977-1...  1977-12-03
# 26292  http://www.billboard.com/charts/hot-100/1981-0...  1981-01-17
# 26745  http://www.billboard.com/charts/hot-100/1989-0...  1989-01-21
# 26798  http://www.billboard.com/charts/hot-100/2002-1...  2002-10-19
#
#        week_position                                   song  \
# 117               38              (Just Like) Starting Over
# 163               67       (Sittin' On) The Dock Of The Bay
# 293               81                                   1999
# 442               70                 A Change Is Gonna Come
# 3891              26                                 Clouds
# 5196              96                             Doin' Time
# 5216              93                                  Donna
# 7009              10                         Free As A Bird
# 7324              80                   Get It While You Can
# 9526               2                              Hypnotize
# 11090             73  I'll Have To Say I Love You In A Song
# 11787             82              It Doesn't Matter Anymore
# 14946             94                     Me And Bobby McGee
# 15009             90                                Melissa
# 16361             36                         Nobody Told Me
# 18148             11                              Real Love
# 23747             79                       Time In A Bottle
# 24957             77                    Watching The Wheels
# 25523             83                       What's Your Name
# 26292             36                                  Woman
# 26745             85                             You Got It
# 26798             55                  You Know You're Right
#
#                       performer  \
# 117                 John Lennon
# 163                Otis Redding
# 293                      Prince
# 442                   Sam Cooke
# 3891               Zach Sobiech
# 5196                    Sublime
# 5216             Ritchie Valens
# 7009                The Beatles
# 7324               Janis Joplin
# 9526       The Notorious B.I.G.
# 11090                 Jim Croce
# 11787               Buddy Holly
# 14946              Janis Joplin
# 15009  The Allman Brothers Band
# 16361               John Lennon
# 18148               The Beatles
# 23747                 Jim Croce
# 24957               John Lennon
# 25523            Lynyrd Skynyrd
# 26292               John Lennon
# 26745               Roy Orbison
# 26798                   Nirvana
#
#                                                songid  instance  \
# 117              (Just Like) Starting OverJohn Lennon         1
# 163      (Sittin' On) The Dock Of The BayOtis Redding         1
# 293                                        1999Prince         1
# 442                   A Change Is Gonna ComeSam Cooke         1
# 3891                               CloudsZach Sobiech         1
# 5196                                Doin' TimeSublime         1
# 5216                              DonnaRitchie Valens         1
# 7009                        Free As A BirdThe Beatles         1
# 7324                 Get It While You CanJanis Joplin         1
# 9526                    HypnotizeThe Notorious B.I.G.         1
# 11090  I'll Have To Say I Love You In A SongJim Croce         1
# 11787            It Doesn't Matter AnymoreBuddy Holly         1
# 14946                  Me And Bobby McGeeJanis Joplin         1
# 15009                 MelissaThe Allman Brothers Band         1
# 16361                       Nobody Told MeJohn Lennon         1
# 18148                            Real LoveThe Beatles         1
# 23747                       Time In A BottleJim Croce         1
# 24957                  Watching The WheelsJohn Lennon         1
# 25523                  What's Your NameLynyrd Skynyrd         1
# 26292                                WomanJohn Lennon         1
# 26745                           You Got ItRoy Orbison         1
# 26798                    You Know You're RightNirvana         1
#
#        previous_week_position  peak_position  weeks_on_chart  year  week  \
# 117                       NaN              1              22  1980    44
# 163                       NaN              1              16  1968     4
# 293                       NaN             12              30  1982    43
# 442                       NaN             31               7  1965     4
# 3891                      NaN             26               2  2013    23
# 5196                      NaN             87               7  1997    51
# 5216                      NaN              2              23  1958    47
# 7009                      NaN              6              11  1995    52
# 7324                      NaN             78               2  1971    36
# 9526                      NaN              1              20  1997    17
# 11090                     NaN              9              14  1974     9
# 11787                     NaN             13              14  1959     8
# 14946                     NaN              1              15  1971     4
# 15009                     NaN             86               2  1972    32
# 16361                     NaN              5              14  1984     3
# 18148                     NaN             11               7  1996    12
# 23747                     NaN              1              15  1973    46
# 24957                     NaN             10              17  1981    13
# 25523                     NaN             13              18  1977    48
# 26292                     NaN              2              20  1981     3
# 26745                     NaN              9              18  1989     3
# 26798                     NaN             45              20  2002    42
#
#        jump_time  max_jump_duration  strict_rule  lenient_rule  \
# 117            0                  0           51            47
# 163            0                  0           69            62
# 293            3               6321           66             0
# 442            0                  0           64             0
# 3891           0                  0           36             0
# 5196           0                  0           53            57
# 5216           0                  0            0            53
# 7009           0                  0           48             0
# 7324           0                  0           42            29
# 9526           0                  0           77            68
# 11090          0                  0           51            44
# 11787          0                  0            0            41
# 14946          0                  0           68            44
# 15009          0                  0           54             0
# 16361          0                  0           45             0
# 18148          0                  0           47             0
# 23747          0                  0           57            51
# 24957          0                  0           47            59
# 25523          0                  0            0            44
# 26292          0                  0           70            36
# 26745          0                  0           67             0
# 26798          0                  0           58            30
#
#        all_time_greatest_artist split  artistdied  wordcup
# 117                           0    []           1        0
# 163                           0    []           1        0
# 293                           1    []           1        0
# 442                           0    []           1        0
# 3891                          0    []           1        0
# 5196                          0    []           1        0
# 5216                          0    []           1        0
# 7009                          1    []           1        0
# 7324                          0    []           1        0
# 9526                          0    []           1        0
# 11090                         0    []           1        0
# 11787                         0    []           1        0
# 14946                         0    []           1        0
# 15009                         0    []           1        0
# 16361                         0    []           1        0
# 18148                         1    []           1        0
# 23747                         0    []           1        0
# 24957                         0    []           1        0
# 25523                         0    []           1        0
# 26292                         0    []           1        0
# 26745                         0    []           1        0
# 26798                         0    []           1        0

# %%
columns_to_drop=feature_name[1:25]
allSong.loc[allSong['songid']=="(Sittin' On) The Dock Of The BayOtis Redding"].drop(columns_to_drop, axis=1)
# Out:
#                                                    url      weekid  \
# 163  http://www.billboard.com/charts/hot-100/1968-0...  1968-01-27
#
#      week_position                              song     performer  \
# 163             67  (Sittin' On) The Dock Of The Bay  Otis Redding
#
#                                            songid  instance  \
# 163  (Sittin' On) The Dock Of The BayOtis Redding         1
#
#      previous_week_position  peak_position  weeks_on_chart  year  week  \
# 163                     NaN              1              16  1968     4
#
#      jump_time  max_jump_duration  strict_rule  lenient_rule  \
# 163          0                  0           69            62
#
#      all_time_greatest_artist split  artistdied  wordcup
# 163                         0    []           1        0

# %%
print(feature_name[1])
columns_to_drop=feature_name[2:26]+[feature_name[0]]
print(columns_to_drop)
df_mody=df_array[1].drop(columns_to_drop, axis=1)
df_mody
# Out:
# christmas
# ['church', 'classical', 'commercials', 'concerts', 'easter', 'fourthofjuly', 'funerals', 'graduations', 'grammys', 'halloween', 'inmovieclueless', 'inmovies', 'inplays', 'intvshows', 'karaoke', 'lullabies', 'mtvawards', 'phonecall', 'politicians', 'sportingevents', 'tvshow', 'weddings', 'wonoscars', 'wordcup', 'artistdied']
#                                                      url      weekid  \
# 1024   http://www.billboard.com/charts/hot-100/2000-0...  2000-01-08
# 2810   http://www.billboard.com/charts/hot-100/2010-1...  2010-12-18
# 3789   http://www.billboard.com/charts/hot-100/2010-1...  2010-12-18
# 8036   http://www.billboard.com/charts/hot-100/1998-0...  1998-01-10
# 9574   http://www.billboard.com/charts/hot-100/1975-1...  1975-12-20
# 12307  http://www.billboard.com/charts/hot-100/1958-1...  1958-12-20
# 12983  http://www.billboard.com/charts/hot-100/2017-0...  2017-01-07
# 14888  http://www.billboard.com/charts/hot-100/2014-1...  2014-12-06
# 15057  http://www.billboard.com/charts/hot-100/1980-1...  1980-12-27
# 15250  http://www.billboard.com/charts/hot-100/2011-1...  2011-11-05
# 16596  http://www.billboard.com/charts/hot-100/2011-0...  2011-01-01
# 17556  http://www.billboard.com/charts/hot-100/1961-1...  1961-12-23
# 17801  http://www.billboard.com/charts/hot-100/1963-1...  1963-12-14
# 18591  http://www.billboard.com/charts/hot-100/1960-1...  1960-12-10
# 18974  http://www.billboard.com/charts/hot-100/2014-1...  2014-12-13
# 19824  http://www.billboard.com/charts/hot-100/1960-1...  1960-12-17
# 22340  http://www.billboard.com/charts/hot-100/2000-1...  2000-12-30
# 25844  http://www.billboard.com/charts/hot-100/1958-1...  1958-12-20
#
#        week_position                                song  \
# 1024              83     All I Want For Christmas Is You
# 2810              79                               Boots
# 3789              25                    Christmas Lights
# 8036              87  Grandma Got Run Over By A Reindeer
# 9574              99       I Believe In Father Christmas
# 12307             57                    Jingle Bell Rock
# 12983             50                      Last Christmas
# 14888             26                 Mary, Did You Know?
# 15057             82          Merry Christmas In The NFL
# 15250             11                           Mistletoe
# 16596            100                           Oh Santa!
# 17556             85      Please Come Home For Christmas
# 17801             60                        Pretty Paper
# 18591             64   Rockin' Around The Christmas Tree
# 18974             65                       Santa Tell Me
# 19824             64                        Silent Night
# 22340             68                 The Christmas Shoes
# 25844             86                     White Christmas
#
#                            performer  \
# 1024                    Mariah Carey
# 2810                     The Killers
# 3789                        Coldplay
# 8036                    Elmo & Patsy
# 9574                       Greg Lake
# 12307                    Bobby Helms
# 12983                          Wham!
# 14888                     Pentatonix
# 15057  Willis "The Guard" & Vigorish
# 15250                  Justin Bieber
# 16596                   Mariah Carey
# 17556                  Charles Brown
# 17801                    Roy Orbison
# 18591                     Brenda Lee
# 18974                  Ariana Grande
# 19824                    Bing Crosby
# 22340                        NewSong
# 25844                    Bing Crosby
#
#                                                   songid  instance  \
# 1024         All I Want For Christmas Is YouMariah Carey         1
# 2810                                    BootsThe Killers         1
# 3789                            Christmas LightsColdplay         1
# 8036      Grandma Got Run Over By A ReindeerElmo & Patsy         1
# 9574              I Believe In Father ChristmasGreg Lake         1
# 12307                        Jingle Bell RockBobby Helms         1
# 12983                                Last ChristmasWham!         1
# 14888                      Mary, Did You Know?Pentatonix         1
# 15057  Merry Christmas In The NFLWillis "The Guard" &...         1
# 15250                             MistletoeJustin Bieber         1
# 16596                              Oh Santa!Mariah Carey         1
# 17556        Please Come Home For ChristmasCharles Brown         1
# 17801                            Pretty PaperRoy Orbison         1
# 18591        Rockin' Around The Christmas TreeBrenda Lee         1
# 18974                         Santa Tell MeAriana Grande         1
# 19824                            Silent NightBing Crosby         1
# 22340                         The Christmas ShoesNewSong         1
# 25844                         White ChristmasBing Crosby         1
#
#        previous_week_position  peak_position  weeks_on_chart  year  week  \
# 1024                      NaN             11              19  2000     1
# 2810                      NaN             79               1  2010    50
# 3789                      NaN             25               3  2010    50
# 8036                      NaN             87               1  1998     2
# 9574                      NaN             95               3  1975    51
# 12307                     NaN             29              19  1958    51
# 12983                     NaN             41               2  2017     1
# 14888                     NaN             26               7  2014    49
# 15057                     NaN             82               3  1980    52
# 15250                     NaN             11              10  2011    44
# 16596                     NaN            100               1  2011    52
# 17556                     NaN             76               2  1961    51
# 17801                     NaN             15               7  1963    50
# 18591                     NaN             14              18  1960    49
# 18974                     NaN             42               5  2014    50
# 19824                     NaN             54               2  1960    50
# 22340                     NaN             42               2  2000    52
# 25844                     NaN             12              13  1958    51
#
#        jump_time  max_jump_duration  strict_rule  lenient_rule  \
# 1024           5               4732           85            58
# 2810           0                  0            0             0
# 3789           0                  0           69            59
# 8036           0                  0           50            17
# 9574           0                  0            0             0
# 12307          5              19369           71            70
# 12983          0                  0           75            63
# 14888          1                728            0            68
# 15057          0                  0            0             0
# 15250          1                 14           77             0
# 16596          0                  0           52            44
# 17556          0                  0            0            37
# 17801          0                  0            0            37
# 18591          5              18634            0            77
# 18974          0                  0           79            44
# 19824          0                  0           45            43
# 22340          0                  0           37            48
# 25844          4                364           73            56
#
#        all_time_greatest_artist split  christmas
# 1024                          1    []          1
# 2810                          0    []          1
# 3789                          0    []          1
# 8036                          0    []          1
# 9574                          0    []          1
# 12307                         0    []          1
# 12983                         0    []          1
# 14888                         0    []          1
# 15057                         0    []          1
# 15250                         1    []          1
# 16596                         1    []          1
# 17556                         0    []          1
# 17801                         0    []          1
# 18591                         1    []          1
# 18974                         0    []          1
# 19824                         0    []          1
# 22340                         0    []          1
# 25844                         0    []          1

# %%
df_BingCrosby=allSong.loc[allSong['performer']=="Bing Crosby"].drop(columns_to_drop, axis=1)
df_BingCrosby
# Out:
#                                                      url      weekid  \
# 759    http://www.billboard.com/charts/hot-100/1960-1...  1960-12-10
# 19824  http://www.billboard.com/charts/hot-100/1960-1...  1960-12-17
# 25844  http://www.billboard.com/charts/hot-100/1958-1...  1958-12-20
#
#        week_position                                        song    performer  \
# 759               79  Adeste Fideles (Oh, Come, All Ye Faithful)  Bing Crosby
# 19824             64                                Silent Night  Bing Crosby
# 25844             86                             White Christmas  Bing Crosby
#
#                                                   songid  instance  \
# 759    Adeste Fideles (Oh, Come, All Ye Faithful)Bing...         1
# 19824                            Silent NightBing Crosby         1
# 25844                         White ChristmasBing Crosby         1
#
#        previous_week_position  peak_position  weeks_on_chart  year  week  \
# 759                       NaN             45               3  1960    49
# 19824                     NaN             54               2  1960    50
# 25844                     NaN             12              13  1958    51
#
#        jump_time  max_jump_duration  strict_rule  lenient_rule  \
# 759            0                  0            0             0
# 19824          0                  0           45            43
# 25844          4                364           73            56
#
#        all_time_greatest_artist split  christmas
# 759                           0    []          0
# 19824                         0    []          1
# 25844                         0    []          1

# %%
print(feature_name[2])
columns_to_drop=feature_name[3:26]+[feature_name[0], feature_name[1]]
print(columns_to_drop)
df_mody=df_array[2].drop(columns_to_drop, axis=1)
df_mody
# Out:
# church
# ['classical', 'commercials', 'concerts', 'easter', 'fourthofjuly', 'funerals', 'graduations', 'grammys', 'halloween', 'inmovieclueless', 'inmovies', 'inplays', 'intvshows', 'karaoke', 'lullabies', 'mtvawards', 'phonecall', 'politicians', 'sportingevents', 'tvshow', 'weddings', 'wonoscars', 'wordcup', 'artistdied', 'christmas']
#                                                      url      weekid  \
# 12284  http://www.billboard.com/charts/hot-100/1972-1...  1972-12-16
# 15413  http://www.billboard.com/charts/hot-100/1972-0...  1972-04-01
# 19824  http://www.billboard.com/charts/hot-100/1960-1...  1960-12-17
# 22711  http://www.billboard.com/charts/hot-100/1974-0...  1974-02-23
#
#        week_position                   song            performer  \
# 12284             97  Jesus Is Just Alright  The Doobie Brothers
# 15413             78     Morning Has Broken          Cat Stevens
# 19824             64           Silent Night          Bing Crosby
# 22711             71      The Lord's Prayer    Sister Janet Mead
#
#                                          songid  instance  \
# 12284  Jesus Is Just AlrightThe Doobie Brothers         1
# 15413             Morning Has BrokenCat Stevens         1
# 19824                   Silent NightBing Crosby         1
# 22711        The Lord's PrayerSister Janet Mead         1
#
#        previous_week_position  peak_position  weeks_on_chart  year  week  \
# 12284                     NaN             35              11  1972    50
# 15413                     NaN              6              14  1972    13
# 19824                     NaN             54               2  1960    50
# 22711                     NaN              4              13  1974     8
#
#        jump_time  max_jump_duration  strict_rule  lenient_rule  \
# 12284          0                  0           31            48
# 15413          0                  0           63            37
# 19824          0                  0           45            43
# 22711          0                  0            0            12
#
#        all_time_greatest_artist split  church
# 12284                         0    []       1
# 15413                         0    []       1
# 19824                         0    []       1
# 22711                         0    []       1

# %%
print(feature_name[3])
columns_to_drop=feature_name[4:26]+[feature_name[0], feature_name[1], feature_name[2]]
print(columns_to_drop)
df_mody=df_array[3].drop(columns_to_drop, axis=1)
df_mody
# Out:
# classical
# ['commercials', 'concerts', 'easter', 'fourthofjuly', 'funerals', 'graduations', 'grammys', 'halloween', 'inmovieclueless', 'inmovies', 'inplays', 'intvshows', 'karaoke', 'lullabies', 'mtvawards', 'phonecall', 'politicians', 'sportingevents', 'tvshow', 'weddings', 'wonoscars', 'wordcup', 'artistdied', 'christmas', 'church']
# Empty DataFrame
# Columns: [url, weekid, week_position, song, performer, songid, instance, previous_week_position, peak_position, weeks_on_chart, year, week, jump_time, max_jump_duration, strict_rule, lenient_rule, all_time_greatest_artist, split, classical]
# Index: []

# %%
print(feature_name[4])
columns_to_drop=feature_name[5:26]+[feature_name[0], feature_name[1], feature_name[2], feature_name[3]]
print(columns_to_drop)
df_mody=df_array[4].loc[df_array[4]['strict_rule']>0].drop(columns_to_drop, axis=1)
df_mody.sort_values(by="year", ascending=True).head(20)
# Out:
# commercials
# ['concerts', 'easter', 'fourthofjuly', 'funerals', 'graduations', 'grammys', 'halloween', 'inmovieclueless', 'inmovies', 'inplays', 'intvshows', 'karaoke', 'lullabies', 'mtvawards', 'phonecall', 'politicians', 'sportingevents', 'tvshow', 'weddings', 'wonoscars', 'wordcup', 'artistdied', 'christmas', 'church', 'classical']
#                                                      url      weekid  \
# 2427   http://www.billboard.com/charts/hot-100/1960-0...  1960-01-16
# 26310  http://www.billboard.com/charts/hot-100/1960-0...  1960-05-07
# 2793   http://www.billboard.com/charts/hot-100/1962-0...  1962-05-26
# 26175  http://www.billboard.com/charts/hot-100/1963-0...  1963-06-22
# 3245   http://www.billboard.com/charts/hot-100/1964-0...  1964-01-25
# 3547   http://www.billboard.com/charts/hot-100/1965-0...  1965-05-15
# 15012  http://www.billboard.com/charts/hot-100/1966-1...  1966-11-12
# 21336  http://www.billboard.com/charts/hot-100/1966-0...  1966-07-30
# 23393  http://www.billboard.com/charts/hot-100/1966-0...  1966-01-22
# 24199  http://www.billboard.com/charts/hot-100/1966-1...  1966-12-03
# 25540  http://www.billboard.com/charts/hot-100/1966-0...  1966-04-09
# 7443   http://www.billboard.com/charts/hot-100/1966-1...  1966-12-31
# 26417  http://www.billboard.com/charts/hot-100/1966-0...  1966-07-30
# 8286   http://www.billboard.com/charts/hot-100/1967-0...  1967-02-11
# 11189  http://www.billboard.com/charts/hot-100/1967-0...  1967-03-25
# 13386  http://www.billboard.com/charts/hot-100/1967-0...  1967-01-21
# 8273   http://www.billboard.com/charts/hot-100/1967-0...  1967-04-15
# 16045  http://www.billboard.com/charts/hot-100/1967-0...  1967-08-26
# 19576  http://www.billboard.com/charts/hot-100/1967-1...  1967-12-30
# 6080   http://www.billboard.com/charts/hot-100/1967-0...  1967-09-30
#
#        week_position                              song  \
# 2427              74                    Beyond The Sea
# 26310             97                   Wonderful World
# 2793             100                         Boom Boom
# 26175             86                          Wipe Out
# 3245              70                    California Sun
# 3547              85                    Catch The Wind
# 15012             65                     Mellow Yellow
# 21336             90                 Sunshine Superman
# 23393             74  These Boots Are Made For Walkin'
# 24199             85           Try A Little Tenderness
# 25540            100          When A Man Loves A Woman
# 7443             100                 Gimme Some Lovin'
# 26417             84               Wouldn't It Be Nice
# 8286              79                    Happy Together
# 11189             71                         I'm A Man
# 13386             85    Let's Spend The Night Together
# 8273              99                        Happy Jack
# 16045             83                     Never My Love
# 19576             77                   She's A Rainbow
# 6080              83                  Everlasting Love
#
#                      performer  \
# 2427               Bobby Darin
# 26310                Sam Cooke
# 2793           John Lee Hooker
# 26175             The Surfaris
# 3245              The Rivieras
# 3547                   Donovan
# 15012                  Donovan
# 21336                  Donovan
# 23393            Nancy Sinatra
# 24199             Otis Redding
# 25540             Percy Sledge
# 7443   The Spencer Davis Group
# 26417           The Beach Boys
# 8286               The Turtles
# 11189  The Spencer Davis Group
# 13386       The Rolling Stones
# 8273                   The Who
# 16045          The Association
# 19576       The Rolling Stones
# 6080             Robert Knight
#
#                                                  songid  instance  \
# 2427                          Beyond The SeaBobby Darin         1
# 26310                          Wonderful WorldSam Cooke         1
# 2793                           Boom BoomJohn Lee Hooker         1
# 26175                              Wipe OutThe Surfaris         1
# 3245                         California SunThe Rivieras         1
# 3547                              Catch The WindDonovan         1
# 15012                              Mellow YellowDonovan         1
# 21336                          Sunshine SupermanDonovan         1
# 23393     These Boots Are Made For Walkin'Nancy Sinatra         1
# 24199               Try A Little TendernessOtis Redding         1
# 25540              When A Man Loves A WomanPercy Sledge         1
# 7443           Gimme Some Lovin'The Spencer Davis Group         1
# 26417                 Wouldn't It Be NiceThe Beach Boys         1
# 8286                          Happy TogetherThe Turtles         1
# 11189                  I'm A ManThe Spencer Davis Group         1
# 13386  Let's Spend The Night TogetherThe Rolling Stones         1
# 8273                                  Happy JackThe Who         1
# 16045                      Never My LoveThe Association         1
# 19576                 She's A RainbowThe Rolling Stones         1
# 6080                      Everlasting LoveRobert Knight         1
#
#        previous_week_position  peak_position  weeks_on_chart  year  week  \
# 2427                      NaN              6              14  1960     2
# 26310                     NaN             12              15  1960    18
# 2793                      NaN             60              10  1962    21
# 26175                     NaN              2              30  1963    25
# 3245                      NaN              5              10  1964     4
# 3547                      NaN             23              10  1965    19
# 15012                     NaN              2              12  1966    45
# 21336                     NaN              1              13  1966    30
# 23393                     NaN              1              14  1966     3
# 24199                     NaN             25              10  1966    48
# 25540                     NaN              1              13  1966    14
# 7443                      NaN              7              13  1966    52
# 26417                     NaN              8              11  1966    30
# 8286                      NaN              1              15  1967     6
# 11189                     NaN             10               9  1967    12
# 13386                     NaN             55               8  1967     3
# 8273                      NaN             24               9  1967    15
# 16045                     NaN              2              14  1967    34
# 19576                     NaN             25               7  1967    52
# 6080                      NaN             13              12  1967    39
#
#        jump_time  max_jump_duration  strict_rule  lenient_rule  \
# 2427           0                  0           58            63
# 26310          0                  0           65            69
# 2793           0                  0           55            50
# 26175          1               1029           43            42
# 3245           0                  0           38             0
# 3547           0                  0           58            29
# 15012          0                  0           32            51
# 21336          0                  0           57             0
# 23393          0                  0           65            43
# 24199          0                  0           62            53
# 25540          0                  0           65            49
# 7443           0                  0           56            45
# 26417          0                  0           71            66
# 8286           0                  0           72            44
# 11189          0                  0           41             0
# 13386          0                  0           50            32
# 8273           0                  0           15            37
# 16045          0                  0           42            45
# 19576          0                  0           34            54
# 6080           0                  0           15            26
#
#        all_time_greatest_artist split  commercials
# 2427                          1    []            1
# 26310                         0    []            1
# 2793                          0    []            1
# 26175                         0    []            1
# 3245                          0    []            1
# 3547                          0    []            1
# 15012                         0    []            1
# 21336                         0    []            1
# 23393                         0    []            1
# 24199                         0    []            1
# 25540                         0    []            1
# 7443                          0    []            1
# 26417                         1    []            1
# 8286                          0    []            1
# 11189                         0    []            1
# 13386                         1    []            1
# 8273                          0    []            1
# 16045                         0    []            1
# 19576                         1    []            1
# 6080                          0    []            1

# %%
allSong.loc[allSong['performer']=="John Lee Hooker"].drop(columns_to_drop, axis=1)
# Out:
#                                                     url      weekid  \
# 2793  http://www.billboard.com/charts/hot-100/1962-0...  1962-05-26
#
#       week_position       song        performer                    songid  \
# 2793            100  Boom Boom  John Lee Hooker  Boom BoomJohn Lee Hooker
#
#       instance  previous_week_position  peak_position  weeks_on_chart  year  \
# 2793         1                     NaN             60              10  1962
#
#       week  jump_time  max_jump_duration  strict_rule  lenient_rule  \
# 2793    21          0                  0           55            50
#
#       all_time_greatest_artist split  commercials
# 2793                         0    []            1

# %%
# feature_name.remove('inmovies')
a=allSong.loc[allSong['inmovies']==1].drop(feature_name, axis=1)
a.loc[a['performer']=="John Lee Hooker"]
# Out:
#                                                     url      weekid  \
# 2793  http://www.billboard.com/charts/hot-100/1962-0...  1962-05-26
#
#       week_position       song        performer                    songid  \
# 2793            100  Boom Boom  John Lee Hooker  Boom BoomJohn Lee Hooker
#
#       instance  previous_week_position  peak_position  weeks_on_chart  year  \
# 2793         1                     NaN             60              10  1962
#
#       week  jump_time  max_jump_duration  strict_rule  lenient_rule  \
# 2793    21          0                  0           55            50
#
#       all_time_greatest_artist split  inmovies
# 2793                         0    []         1

# %%
print(feature_name[5])
columns_to_drop=feature_name[6:26]+[feature_name[0], feature_name[1], feature_name[2], feature_name[3]],feature_name[4]
print(columns_to_drop)
df_mody=df_array[5].loc[df_array[5]['strict_rule']>0].drop(columns_to_drop, axis=1)
df_mody
# Out:
# concerts
# (['easter', 'fourthofjuly', 'funerals', 'graduations', 'grammys', 'halloween', 'inmovieclueless', 'inmovies', 'inplays', 'intvshows', 'karaoke', 'lullabies', 'mtvawards', 'phonecall', 'politicians', 'sportingevents', 'tvshow', 'weddings', 'wonoscars', 'wordcup', 'artistdied', 'christmas', 'church', 'classical'], 'commercials')
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-67-aa7965dab10d> in <module>
#       2 columns_to_drop=feature_name[6:26]+[feature_name[0], feature_name[1], feature_name[2], feature_name[3]],feature_name[4]
#       3 print(columns_to_drop)
# ----> 4 df_mody=df_array[5].loc[df_array[5]['strict_rule']>0].drop(columns_to_drop, axis=1)
#       5 df_mody
#
# ~\Anaconda3\envs\python36\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3695                                            index=index, columns=columns,
#    3696                                            level=level, inplace=inplace,
# -> 3697                                            errors=errors)
#    3698
#    3699     @rewrite_axis_style_signature('mapper', [('copy', True),
#
# ~\Anaconda3\envs\python36\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3109         for axis, labels in axes.items():
#    3110             if labels is not None:
# -> 3111                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3112
#    3113         if inplace:
#
# ~\Anaconda3\envs\python36\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors)
#    3141                 new_axis = axis.drop(labels, level=level, errors=errors)
#    3142             else:
# -> 3143                 new_axis = axis.drop(labels, errors=errors)
#    3144             result = self.reindex(**{axis_name: new_axis})
#    3145
#
# ~\Anaconda3\envs\python36\lib\site-packages\pandas\core\indexes\base.py in drop(self, labels, errors)
#    4397         arr_dtype = 'object' if self.dtype == 'object' else None
#    4398         labels = com._index_labels_to_array(labels, dtype=arr_dtype)
# -> 4399         indexer = self.get_indexer(labels)
#    4400         mask = indexer == -1
#    4401         if mask.any():
#
# ~\Anaconda3\envs\python36\lib\site-packages\pandas\core\indexes\base.py in get_indexer(self, target, method, limit, tolerance)
#    3257                                  'backfill or nearest reindexing')
#    3258
# -> 3259             indexer = self._engine.get_indexer(target._ndarray_values)
#    3260
#    3261         return _ensure_platform_int(indexer)
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_indexer()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.lookup()
#
# TypeError: unhashable type: 'list'
